# %% [markdown]
# # 1.String :smile::tada:

# %%
Name = 'Shan'
Position = 'Data Scientist'

print (Name +' is a '+ Position)
# Out:
# Shan is a Data Scientist

# %% [markdown]
# # 2.Slicing :thumbsup:

# %%
print (Name)

print (Position[5:])
# Out:
# Shan
# Scientist

# %% [markdown]
# # 3.Replace,Lower,upper :snake:

# %%
epl = 'Arsenal'

print (epl)

#upper 

print (epl.upper())

# Lower 

print (epl.lower())


# Replace

print (epl)

epl1 = epl.replace ('Arsenal', 'Wenger')

print(epl1) 

#:bulb:
# Out:
# Arsenal
# ARSENAL
# arsenal
# Arsenal
# Wenger

# %% [markdown]
# # 4.Fstring :bulb:

# %%
name = 'shan'

age = '36'

print (f"{name} and his age is {age}")

print (dir())

print (help(str.strip))
# Out:
# shan and his age is 36
# ['In', 'Name', 'Out', 'Position', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '__vsc_ipynb_file__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'age', 'epl', 'epl1', 'exit', 'get_ipython', 'name', 'open', 'quit']
# Help on method_descriptor:
#
# strip(self, chars=None, /) unbound builtins.str method
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.
#
# None
